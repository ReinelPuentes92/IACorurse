# %% [markdown]
# # Explorar nosso Dataset

# %%
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %%
DATASET_FRACTION = 0.1

dataset_path = 'data/images/home/sdf/marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv'

dataset_df = pd.read_csv(dataset_path).sample(frac=DATASET_FRACTION)
dataset_df.columns
# Out:
# Index(['Uniq Id', 'Product Name', 'Brand Name', 'Asin', 'Category',
#        'Upc Ean Code', 'List Price', 'Selling Price', 'Quantity',
#        'Model Number', 'About Product', 'Product Specification',
#        'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image',
#        'Variants', 'Sku', 'Product Url', 'Stock', 'Product Details',
#        'Dimensions', 'Color', 'Ingredients', 'Direction To Use',
#        'Is Amazon Seller', 'Size Quantity Variant', 'Product Description',
#        'LocalImage'],
#       dtype='object')

# %%
#dataset_df.head(5)
dataset_df[['Product Name', 'Image']].head(5)
# Out:
#                                                                                                                                    Product Name  \
# 144  Sweet Jojo Designs Black and Blush Pink Shabby Chic Watercolor Floral Girl Twin Kids Children's Bedding Comforter Set-4 Pieces-Rose Flower
# 40                                                                                                       Minnie Bow-Tique Why Hello! Cell Phone
# 195                                                                                                             TCG Toys 20Q Sport, Gold/Silver
# 54                                                                         Fantasy Flight Games Star Wars RPG: Allies & Adversaries, Multicolor
# 237                                                                                                             Batman Cups, 9 oz., Party Favor
#
#                                                                   Image
# 144  https://images-na.ssl-images-amazon.com/images/I/517oKWub%2BRL.jpg
# 40     https://images-na.ssl-images-amazon.com/images/I/51Yr5vMioQL.jpg
# 195    https://images-na.ssl-images-amazon.com/images/I/51HZ18ciG8L.jpg
# 54     https://images-na.ssl-images-amazon.com/images/I/413hNom4FFL.jpg
# 237    https://images-na.ssl-images-amazon.com/images/I/41nmT99yvjL.jpg
