# %% [markdown]
# # Exploramos nuestro Dataset

# %% [markdown]
# Inslamos pandas
#
# pip install pandas

# %%
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
DATASET_FRACTION = 0.1

dataset_path = 'data/images/home/sdf/marketing_sample_for_amazon_com-ecommerce__20200101_20200131__10k_data.csv' #Path relativo

dataset_df = pd.read_csv(dataset_path).sample(frac=DATASET_FRACTION)
dataset_df.columns
# Out:
# Index(['Uniq Id', 'Product Name', 'Brand Name', 'Asin', 'Category',
#        'Upc Ean Code', 'List Price', 'Selling Price', 'Quantity',
#        'Model Number', 'About Product', 'Product Specification',
#        'Technical Details', 'Shipping Weight', 'Product Dimensions', 'Image',
#        'Variants', 'Sku', 'Product Url', 'Stock', 'Product Details',
#        'Dimensions', 'Color', 'Ingredients', 'Direction To Use',
#        'Is Amazon Seller', 'Size Quantity Variant', 'Product Description'],
#       dtype='str')

# %%
dataset_df[['Product Name', 'Category','Image']].head(5)
# Out:
#                                            Product Name  \
# 5686  Buffalo Games - Night & Day Collection - Paris...
# 4880  Rollplay 6 Volt GMC Yukon Denali Fire Rescue T...
# 1904  Creativity Street Chenille Stems/Pipe Cleaners...
# 5778  Rubie's Marvel Classic Child's American Dream ...
# 9132  Amscan 270249 Pin The Moustache On The Cow Gam...
#
#                                                Category  \
# 5686            Toys & Games | Puzzles | Jigsaw Puzzles
# 4880  Toys & Games | Tricycles, Scooters & Wagons | ...
# 1904  Arts, Crafts & Sewing | Crafting | Craft Suppl...
# 5778  Clothing, Shoes & Jewelry | Costumes & Accesso...
# 9132                      Toys & Games | Party Supplies
#
#                                                   Image
# 5686  https://images-na.ssl-images-amazon.com/images...
# 4880  https://images-na.ssl-images-amazon.com/images...
# 1904  https://images-na.ssl-images-amazon.com/images...
# 5778  https://images-na.ssl-images-amazon.com/images...
# ...
